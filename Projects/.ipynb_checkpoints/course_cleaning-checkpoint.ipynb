# %%
import pandas as pd
import numpy as np
import re

courses_df = pd.read_csv('all_slu_courses.csv')
courses_df
# Out:
#                                            Course Title  \
# 0      AEP 0100 - Writing and Grammar Level 1: Beginner
# 1     AEP 0120 - Reading and Vocabulary Level 1: Beg...
# 2     AEP 0130 - Listening and Speaking Level 1: Beg...
# 3     AEP 0200 - Writing and Grammar Level 2: High B...
# 4     AEP 0220 - Reading and Vocabulary Level 2: Hig...
# ...                                                 ...
# 6393  WGST 6790X - Feminist Approaches to Social Wor...
# 6394              WGST 6833 - Employment Discrimination
# 6395                             WGST 6875 - Family Law
# 6396          WGST 6930 - Special Topics: Women Studies
# 6397                      WGST 6980 - Independent Study
#
#                                                 Credits Prerequisites  \
# 0                                  Credit(s): 4 Credits           NaN
# 1                                  Credit(s): 4 Credits           NaN
# 2                                  Credit(s): 4 Credits           NaN
# 3                                  Credit(s): 4 Credits           NaN
# 4                                  Credit(s): 4 Credits           NaN
# ...                                                 ...           ...
# 6393                               Credit(s): 3 Credits           NaN
# 6394                               Credit(s): 3 Credits           NaN
# 6395                               Credit(s): 3 Credits           NaN
# 6396       Credit(s): 3 Credits (Repeatable for credit)           NaN
# 6397  Credit(s): 1 or 3 Credits (Repeatable for credit)           NaN
#
#      Concurrent Enrollment                              Major
# 0                      NaN     Academic English Program (AEP)
# 1                      NaN     Academic English Program (AEP)
# 2                      NaN     Academic English Program (AEP)
# 3                      NaN     Academic English Program (AEP)
# 4                      NaN     Academic English Program (AEP)
# ...                    ...                                ...
# 6393                   NaN  Women's and Gender Studies (WGST)
# 6394                   NaN  Women's and Gender Studies (WGST)
# 6395                   NaN  Women's and Gender Studies (WGST)
# 6396                   NaN  Women's and Gender Studies (WGST)
# 6397                   NaN  Women's and Gender Studies (WGST)
#
# [6398 rows x 5 columns]

# %%
def extract_course_number_without_regex(title):
    parts = title.split()
    for part in parts:
        if part.isdigit() and len(part) == 4:
            return int(part)
    return None

courses_df['Course Number'] = courses_df['Course Title'].apply(extract_course_number_without_regex)
filtered_courses_df = courses_df[courses_df['Course Number'] < 5000]
filtered_courses_df = filtered_courses_df.drop(columns=['Course Number'])

# %%
def split_course_title(title):
    parts = title.split(" - ", 1)
    if len(parts) == 2:
        return parts[0], parts[1]
    return title, ""  # In case there is no " - " in the title

filtered_courses_df[['Course Name', 'Course Details']] = filtered_courses_df['Course Title'].apply(lambda x: pd.Series(split_course_title(x)))
filtered_courses_df = filtered_courses_df.drop(columns=['Course Title'])

# %%
import re

def process_credits(credits):
    repeatable = "Repeatable for credit" in credits
    # Extract all numeric values, including ranges (ie. 1-3 Credits)
    numeric_parts = re.findall(r'\d+', credits)
    # Convert numeric parts to integers and find the maximum value
    numeric_values = [int(part) for part in numeric_parts]
    max_credits = max(numeric_values) if numeric_values else None
    return max_credits, repeatable

filtered_courses_df[['Number of Credits', 'Repeatable']] = filtered_courses_df['Credits'].apply(lambda x: pd.Series(process_credits(x)))
filtered_courses_df['Repeatable'] = filtered_courses_df['Repeatable'].astype(bool)
filtered_courses_df = filtered_courses_df.drop(columns=['Credits'])

# %%
filtered_courses_df['Concurrent Enrollment'] = ~filtered_courses_df['Concurrent Enrollment'].isna()

# %%
prerequisites_cleaned = filtered_courses_df.query("'Course Name' == 'CSCI 2050'")['Prerequisites']
prerequisites_cleaned
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 prerequisites_cleaned = filtered_courses_df.query("'Course Name' == 'CSCI 2050'")['Prerequisites']
#       2 prerequisites_cleaned
#
# NameError: name 'filtered_courses_df' is not defined

# %%
filtered_courses_df.head(50)
# Out:
#                       Prerequisites  Concurrent Enrollment  \
# 0                               NaN                  False
# 1                               NaN                  False
# 2                               NaN                  False
# 3                               NaN                  False
# 4                               NaN                  False
# 5                               NaN                  False
# 6                               NaN                  False
# 7                               NaN                  False
# 8                               NaN                  False
# 10                              NaN                  False
# 12                              NaN                  False
# 14                              NaN                  False
# 15                              NaN                  False
# 17                              NaN                  False
# 19                              NaN                  False
# 21                              NaN                  False
# 23                              NaN                  False
# 25                              NaN                  False
# 26                              NaN                  False
# 27                              NaN                  False
# 28                              NaN                  False
# 29                              NaN                  False
# 30                              NaN                  False
# 31                              NaN                  False
# 32               BIZ 1000, BIZ 1001                  False
# 33              ACCT 2200, BIZ 1002                  False
# 34                              NaN                  False
# 35                              NaN                  False
# 36              ACCT 2200, BIZ 1002                  False
# 37                        ACCT 2200                  False
# 38                        ACCT 2200                  False
# 39              ACCT 2220, BTM 2500                  False
# 40                              NaN                  False
# 41                              NaN                  False
# 42                        ACCT 3110                  False
# 43                        ACCT 4110                  False
# 44              ACCT 3110, BTM 2000                  False
# 45                        ACCT 3110                  False
# 46             ACCT 4110, ACCT 4250                   True
# 47    ACCT 3110, BTM 2500, BIZ 3000                  False
# 48                              NaN                  False
# 49                              NaN                  False
# 70                              NaN                  False
# 71                              NaN                  False
# 72  AENG 1002, MENG 1002, PHYS 1610                   True
# 73                              NaN                  False
# 74             CORE 1000, CORE 1500                   True
# 75                              NaN                  False
# 76                              NaN                  False
# 77             AENG 2000, AENG 2020                  False
#
#                              Major Course Name  \
# 0   Academic English Program (AEP)    AEP 0100
# 1   Academic English Program (AEP)    AEP 0120
# 2   Academic English Program (AEP)    AEP 0130
# 3   Academic English Program (AEP)    AEP 0200
# 4   Academic English Program (AEP)    AEP 0220
# 5   Academic English Program (AEP)    AEP 0230
# 6   Academic English Program (AEP)    AEP 0250
# 7   Academic English Program (AEP)    AEP 0300
# 8   Academic English Program (AEP)    AEP 0310
# 10  Academic English Program (AEP)    AEP 0320
# 12  Academic English Program (AEP)    AEP 0330
# 14  Academic English Program (AEP)    AEP 0350
# 15  Academic English Program (AEP)    AEP 0400
# 17  Academic English Program (AEP)    AEP 0410
# 19  Academic English Program (AEP)    AEP 0411
# 21  Academic English Program (AEP)    AEP 0420
# 23  Academic English Program (AEP)    AEP 0430
# 25  Academic English Program (AEP)    AEP 0450
# 26  Academic English Program (AEP)    AEP 0500
# 27  Academic English Program (AEP)    AEP 0510
# 28  Academic English Program (AEP)    AEP 0520
# 29  Academic English Program (AEP)    AEP 0530
# 30  Academic English Program (AEP)    AEP 0930
# 31  Academic English Program (AEP)    AEP 1410
# 32               Accounting (ACCT)   ACCT 2200
# 33               Accounting (ACCT)   ACCT 2220
# 34               Accounting (ACCT)   ACCT 2930
# 35               Accounting (ACCT)   ACCT 2980
# 36               Accounting (ACCT)   ACCT 3060
# 37               Accounting (ACCT)   ACCT 3110
# 38               Accounting (ACCT)   ACCT 3160
# 39               Accounting (ACCT)   ACCT 3220
# 40               Accounting (ACCT)   ACCT 3930
# 41               Accounting (ACCT)   ACCT 3980
# 42               Accounting (ACCT)   ACCT 4110
# 43               Accounting (ACCT)   ACCT 4200
# 44               Accounting (ACCT)   ACCT 4250
# 45               Accounting (ACCT)   ACCT 4300
# 46               Accounting (ACCT)   ACCT 4400
# 47               Accounting (ACCT)   ACCT 4910
# 48               Accounting (ACCT)   ACCT 4930
# 49               Accounting (ACCT)   ACCT 4980
# 70    Aerospace Engineering (AENG)   AENG 1001
# 71    Aerospace Engineering (AENG)   AENG 1002
# 72    Aerospace Engineering (AENG)   AENG 2000
# 73    Aerospace Engineering (AENG)   AENG 2020
# 74    Aerospace Engineering (AENG)   AENG 2910
# 75    Aerospace Engineering (AENG)   AENG 2930
# 76    Aerospace Engineering (AENG)   AENG 2980
# 77    Aerospace Engineering (AENG)   AENG 3000
#
#                                        Course Details  Number of Credits  \
# 0               Writing and Grammar Level 1: Beginner                  4
# 1            Reading and Vocabulary Level 1: Beginner                  4
# 2            Listening and Speaking Level 1: Beginner                  4
# 3          Writing and Grammar Level 2: High Beginner                  4
# 4       Reading and Vocabulary Level 2: High Beginner                  4
# 5       Listening and Speaking Level 2: High Beginner                  4
# 6      English through Service Level 2: High Beginner                  1
# 7           Writing and Grammar Level 3: Intermediate                  4
# 8            Exploring Cultures Level 3: Intermediate                  3
# 10       Reading and Vocabulary Level 3: Intermediate                  3
# 12       Listening and Speaking Level 3: Intermediate                  4
# 14      English through Service Level 3: Intermediate                  1
# 15     Writing and Grammar Level 4: High Intermediate                  4
# 17     Contemporary Issues Level 4: High Intermediate                  3
# 19  People, Places, Connections: An Introduction t...                  3
# 21  Reading and Vocabulary Level 4: High Intermediate                  3
# 23    Listening & Speaking Level 4: High Intermediate                  4
# 25  English through Service Level 4: High Intermed...                  1
# 26          Writing and Grammar Level 5: Low Advanced                  4
# 27  Intercultural Communication Level 5: Low Advanced                  3
# 28       Reading and Vocabulary Level 5: Low Advanced                  3
# 29       Listening and Speaking Level 5: Low Advanced                  4
# 30                                     Special Topics                  4
# 31  People, Places, Connections: An Introduction t...                  3
# 32                               Financial Accounting                  3
# 33                     Accounting for Decision Making                  3
# 34                                     Special Topics                  3
# 35                                  Independent Study                  3
# 36                 Accounting and Business Consulting                  3
# 37                              Financial Reporting I                  3
# 38  International Accounting for Global Organizations                  3
# 39                                    Cost Management                  3
# 40                                     Special Topics                  3
# 41                                  Independent Study                  3
# 42                             Financial Reporting II                  3
# 43                          Accounting Data Analytics                  3
# 44                     Accounting Information Systems                  3
# 45                               Federal Income Tax I                  3
# 46                                           Auditing                  3
# 47                              Accounting Internship                  3
# 48                                     Special Topics                  3
# 49                                  Independent Study                  3
# 70  Introduction to Aerospace & Mechanical Enginee...                  1
# 71                  Computer-Aided Engineering Design                  1
# 72                      Intro to Aeronautics & Astron                  3
# 73         Introduction to Aero and Astro Engineering                  1
# 74                                Co-op with Industry                  3
# 75                                     Special Topics                  3
# 76                                  Independent Study                  3
# 77                                        Performance                  3
#
#     Repeatable
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 10       False
# 12       False
# 14       False
# 15       False
# 17       False
# 19       False
# 21       False
# 23       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34        True
# 35        True
# 36       False
# 37       False
# 38       False
# 39       False
# 40        True
# 41        True
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47        True
# 48        True
# 49        True
# 70       False
# 71       False
# 72       False
# 73       False
# 74        True
# 75        True
# 76        True
# 77       False

# %%
out_fileName = 'cleaned_slu_courses.csv'
filtered_courses_df.to_csv(out_fileName, index=False)

# %%
courses_df = pd.read_csv('cleaned_slu_courses.csv')

def clean_prerequisites(prereq_str):
    if pd.isnull(prereq_str):
        return None
    # Remove quotation marks
    prereq_str = prereq_str.replace('"', '').replace("'", "")
    return prereq_str

courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)
# Out:
# ['AEP\xa00100' 'AEP\xa00120' 'AEP\xa00130' ... 'WGST\xa04930'
#  'WGST\xa04960' 'WGST\xa04980']

# %%
courses_df = pd.read_csv('cleaned_slu_courses.csv')


# Define a function to clean the prerequisites
def clean_prerequisites(prereq_str):
    if pd.isnull(prereq_str):
        return None
    # Remove quotation marks
    prereq_str = prereq_str.replace('"', '').replace("'", "")
    # Split by comma
    prereq_list = prereq_str.split(',')
    # Strip whitespace and remove duplicates
    prereq_list = list(dict.fromkeys([prereq.strip() for prereq in prereq_list]))
    # Join back into a single string with commas
    return ', '.join(prereq_list)

# Apply the cleaning function to the 'Prerequisites' column
courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# %%
out_fileName = 'cleaned_slu_courses2.csv'
courses_df.to_csv(out_fileName, index=False)

# %%
import numpy as np
import pandas as pd

course = 'CSCI 2100'
courses_df = pd.read_csv('cleaned_slu_courses2.csv')

prerequisites_cleaned = courses_df.query('Course Name' == 'CSCI 2050')['Prerequisites']
prerequisites_cleaned


# # Replace NaN values with an empty string
# courses_df['Prerequisites'] = courses_df['Prerequisites'].replace(np.nan, '')

# # Function to clean and split prerequisites
# def clean_prerequisites(prerequisite_string):
#     if prerequisite_string:
#         # Replace non-breaking spaces with regular spaces
#         cleaned_string = prerequisite_string.replace('\xa0', ' ')
#         # Split the string into a list if there are multiple prerequisites
#         prerequisites_list = [prereq.strip() for prereq in cleaned_string.split(',')]
#         return prerequisites_list
#     return []

# # Apply the function to the 'Prerequisites' column
# courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# # Retrieve the cleaned prerequisites for 'CSCI 2100'

# course = 'CSCI 2050'
# # prerequisites_cleaned = courses_df[courses_df['Course Name'] == course]['Prerequisites'].values
# # prerequisites_cleaned = courses_df.loc[courses_df['Course Name'] == course, 'Prerequisites']
# # prerequisites_cleaned = courses_df.query("'Course Name' == 'CSCI 2050'")['Prerequisites']
# prerequisites_cleaned = courses_df[courses_df['Course Name'] == course].groupby('Course Name')['Prerequisites'].apply(list)

# print(prerequisites_cleaned)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7960\24127464.py in ?()
#       3
#       4 course = 'CSCI 2100'
#       5 courses_df = pd.read_csv('cleaned_slu_courses2.csv')
#       6
# ----> 7 prerequisites_cleaned = courses_df.query('Course Name' == 'CSCI 2050')['Prerequisites']
#       8 prerequisites_cleaned
#       9
#      10
#
# c:\Users\payto\Desktop\Other_CS\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, expr, inplace, **kwargs)
#    4816         """
#    4817         inplace = validate_bool_kwarg(inplace, "inplace")
#    4818         if not isinstance(expr, str):
#    4819             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4820             raise ValueError(msg)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
#    4823         res = self.eval(expr, **kwargs)
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %%
import numpy as np
import pandas as pd

course = 'CSCI 2100'
file_path = 'cleaned_slu_courses2.csv'

# Load the CSV file
courses_df = pd.read_csv(file_path)

# Replace NaN values with an empty string
courses_df['Prerequisites'] = courses_df['Prerequisites'].replace(np.nan, '')

# Clean the 'Course Name' column by removing leading/trailing spaces and non-breaking spaces
courses_df['Course Name'] = courses_df['Course Name'].str.strip().str.replace('\xa0', ' ')

# Function to clean and split prerequisites
def clean_prerequisites(prerequisite_string):
    if prerequisite_string:
        # Replace non-breaking spaces with regular spaces
        cleaned_string = prerequisite_string.replace('\xa0', ' ')
        # Split the string into a list if there are multiple prerequisites
        prerequisites_list = [prereq.strip() for prereq in cleaned_string.split(',')]
        return prerequisites_list
    return []

# Apply the function to the 'Prerequisites' column
courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# Clean the target course name
cleaned_course = course.strip().replace('\xa0', ' ')

# Retrieve the cleaned prerequisites for the target course
prerequisites_cleaned = courses_df[courses_df['Course Name'] == cleaned_course]['Prerequisites']

# Check if the prerequisites series is empty
if not prerequisites_cleaned.empty:
    prerequisites_list = prerequisites_cleaned.values[0]
    print(prerequisites_list)
else:
    print(f"No prerequisites found for course {cleaned_course}")
