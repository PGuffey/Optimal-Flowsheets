# %%
import pandas as pd
import numpy as np
import re

courses_df = pd.read_csv('all_slu_courses.csv')
courses_df

# %%
def extract_course_number_without_regex(title):
    parts = title.split()
    for part in parts:
        if part.isdigit() and len(part) == 4:
            return int(part)
    return None

courses_df['Course Number'] = courses_df['Course Title'].apply(extract_course_number_without_regex)
filtered_courses_df = courses_df[courses_df['Course Number'] < 5000]
filtered_courses_df = filtered_courses_df.drop(columns=['Course Number'])

# %%
def split_course_title(title):
    parts = title.split(" - ", 1)
    if len(parts) == 2:
        return parts[0], parts[1]
    return title, ""  # In case there is no " - " in the title

filtered_courses_df[['Course Name', 'Course Details']] = filtered_courses_df['Course Title'].apply(lambda x: pd.Series(split_course_title(x)))
filtered_courses_df = filtered_courses_df.drop(columns=['Course Title'])

# %%
import re

def process_credits(credits):
    repeatable = "Repeatable for credit" in credits
    # Extract all numeric values, including ranges (ie. 1-3 Credits)
    numeric_parts = re.findall(r'\d+', credits)
    # Convert numeric parts to integers and find the maximum value
    numeric_values = [int(part) for part in numeric_parts]
    max_credits = max(numeric_values) if numeric_values else None
    return max_credits, repeatable

filtered_courses_df[['Number of Credits', 'Repeatable']] = filtered_courses_df['Credits'].apply(lambda x: pd.Series(process_credits(x)))
filtered_courses_df['Repeatable'] = filtered_courses_df['Repeatable'].astype(bool)
filtered_courses_df = filtered_courses_df.drop(columns=['Credits'])

# %%
filtered_courses_df['Concurrent Enrollment'] = ~filtered_courses_df['Concurrent Enrollment'].isna()

# %%
prerequisites_cleaned = filtered_courses_df.query("'Course Name' == 'CSCI 2050'")['Prerequisites']
prerequisites_cleaned

# %%
filtered_courses_df.head(50)

# %%
out_fileName = 'cleaned_slu_courses.csv'
filtered_courses_df.to_csv(out_fileName, index=False)

# %%
courses_df = pd.read_csv('cleaned_slu_courses.csv')

def clean_prerequisites(prereq_str):
    if pd.isnull(prereq_str):
        return None
    # Remove quotation marks
    prereq_str = prereq_str.replace('"', '').replace("'", "")
    return prereq_str

courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# %%
courses_df = pd.read_csv('cleaned_slu_courses.csv')


# Define a function to clean the prerequisites
def clean_prerequisites(prereq_str):
    if pd.isnull(prereq_str):
        return None
    # Remove quotation marks
    prereq_str = prereq_str.replace('"', '').replace("'", "")
    # Split by comma
    prereq_list = prereq_str.split(',')
    # Strip whitespace and remove duplicates
    prereq_list = list(dict.fromkeys([prereq.strip() for prereq in prereq_list]))
    # Join back into a single string with commas
    return ', '.join(prereq_list)

# Apply the cleaning function to the 'Prerequisites' column
courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# %%
out_fileName = 'cleaned_slu_courses2.csv'
courses_df.to_csv(out_fileName, index=False)

# %%
import numpy as np
import pandas as pd

course = 'CSCI 2100'
courses_df = pd.read_csv('cleaned_slu_courses2.csv')

prerequisites_cleaned = courses_df.query('Course Name' == 'CSCI 2050')['Prerequisites']
prerequisites_cleaned


# # Replace NaN values with an empty string
# courses_df['Prerequisites'] = courses_df['Prerequisites'].replace(np.nan, '')

# # Function to clean and split prerequisites
# def clean_prerequisites(prerequisite_string):
#     if prerequisite_string:
#         # Replace non-breaking spaces with regular spaces
#         cleaned_string = prerequisite_string.replace('\xa0', ' ')
#         # Split the string into a list if there are multiple prerequisites
#         prerequisites_list = [prereq.strip() for prereq in cleaned_string.split(',')]
#         return prerequisites_list
#     return []

# # Apply the function to the 'Prerequisites' column
# courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# # Retrieve the cleaned prerequisites for 'CSCI 2100'

# course = 'CSCI 2050'
# # prerequisites_cleaned = courses_df[courses_df['Course Name'] == course]['Prerequisites'].values
# # prerequisites_cleaned = courses_df.loc[courses_df['Course Name'] == course, 'Prerequisites']
# # prerequisites_cleaned = courses_df.query("'Course Name' == 'CSCI 2050'")['Prerequisites']
# prerequisites_cleaned = courses_df[courses_df['Course Name'] == course].groupby('Course Name')['Prerequisites'].apply(list)

# print(prerequisites_cleaned)

# %%
import numpy as np
import pandas as pd

course = 'CSCI 2100'
file_path = 'cleaned_slu_courses2.csv'

# Load the CSV file
courses_df = pd.read_csv(file_path)

# Replace NaN values with an empty string
courses_df['Prerequisites'] = courses_df['Prerequisites'].replace(np.nan, '')

# Clean the 'Course Name' column by removing leading/trailing spaces and non-breaking spaces
courses_df['Course Name'] = courses_df['Course Name'].str.strip().str.replace('\xa0', ' ')

# Function to clean and split prerequisites
def clean_prerequisites(prerequisite_string):
    if prerequisite_string:
        # Replace non-breaking spaces with regular spaces
        cleaned_string = prerequisite_string.replace('\xa0', ' ')
        # Split the string into a list if there are multiple prerequisites
        prerequisites_list = [prereq.strip() for prereq in cleaned_string.split(',')]
        return prerequisites_list
    return []

# Apply the function to the 'Prerequisites' column
courses_df['Prerequisites'] = courses_df['Prerequisites'].apply(clean_prerequisites)

# Clean the target course name
cleaned_course = course.strip().replace('\xa0', ' ')

# Retrieve the cleaned prerequisites for the target course
prerequisites_cleaned = courses_df[courses_df['Course Name'] == cleaned_course]['Prerequisites']

# Check if the prerequisites series is empty
if not prerequisites_cleaned.empty:
    prerequisites_list = prerequisites_cleaned.values[0]
    print(prerequisites_list)
else:
    print(f"No prerequisites found for course {cleaned_course}")

# %%
import numpy as np
import pandas as pd


file_path = r'C:\Users\guffe\Desktop\Computer_Science\Projects\Optimal-Flowsheets\Projects\CSV_iterations\cleaned_slu_courses2.csv'

df = pd.read_csv(file_path)

print(df.dtypes)
# Print the data type of the 'Prerequisites' column
print(df['Prerequisites'].dtype)
# Print unique values in the 'Prerequisites' column
print(df['Prerequisites'].unique())

# Print the first 10 values in the 'Prerequisites' column
print(df['Prerequisites'].head(10))
# Out:
# Prerequisites            object
# Concurrent Enrollment      bool
# Major                    object
# Course Name              object
# Course Details           object
# Credits                   int64
# Repeatable                 bool
# dtype: object
# object
# [nan 'BIZ\xa01000, BIZ\xa01001' 'ACCT\xa02200, BIZ\xa01002' 'ACCT\xa02200'
#  'ACCT\xa02220, BTM\xa02500' 'ACCT\xa03110' 'ACCT\xa04110'
#  'ACCT\xa03110, BTM\xa02000' 'ACCT\xa04110, ACCT\xa04250'
#  'ACCT\xa03110, BTM\xa02500, BIZ\xa03000'
#  'AENG\xa01002, MENG\xa01002, PHYS\xa01610' 'CORE\xa01000, CORE\xa01500'
#  'AENG\xa02000, AENG\xa02020' 'AENG\xa03150' 'CSCI\xa01060'
#  'MENG\xa03200, MENG\xa02310, MATH\xa03270' 'AENG\xa03230, MATH\xa03270'
#  'MENG\xa03110' 'AENG\xa02910' 'AENG\xa03000, AENG\xa04400' 'AENG\xa04004'
#  'AENG\xa03100' 'AENG\xa03000, AENG\xa04110' 'AENG\xa03230'
#  'AENG\xa03000, AENG\xa03410' 'AENG\xa04400' 'AENG\xa04110' 'AENG\xa03910'
#  'AES\xa01010, AES\xa02010' 'PSY\xa01010' 'ANTH\xa02210' 'ANTH\xa01200'
#  'SOC\xa01100, SOC\xa01110, SOC\xa01120, ANTH\xa01200'
#  'ANTH\xa04240, ANTH\xa04530, ANTH\xa04710, SOC\xa02000, SOC\xa04015, SOC\xa04025'
#  'AR\xa01010' 'ART\xa02000, ART\xa02100, ART\xa02120, ART\xa02150'
#  'ART\xa02200' 'ART\xa02450' 'ART\xa02500' 'ART\xa02700' 'ART\xa02800'
#  'ART\xa03200' 'ART\xa03450' 'ART\xa03500' 'ART\xa03700' 'ART\xa03800'
#  'CORE\xa01500' 'MATH\xa01200' 'FSCI\xa02150, FSCI\xa02250' 'ASCI\xa02910'
#  'FSCI\xa02650' 'ASCI\xa04012' 'PHIL\xa01700, PHIL\xa01707, PHIL\xa02050'
#  'ASCI\xa04050' 'ECON\xa01900' 'ASCI\xa03910' 'ASCI\xa03915'
#  'BIOL\xa01240, BIOL\xa01245, BIOL\xa01260, BIOL\xa01265'
#  'BIOL\xa01240, BIOL\xa01260, BIOL\xa01245, BIOL\xa01265, CHEM\xa01110, CHEM\xa01130, CHEM\xa01120, CHEM\xa01140'
#  'BIOL\xa03020, CHEM\xa04620'
#  'BIOL\xa01240, BIOL\xa01245, BIOL\xa01260, BIOL\xa01265, CHEM\xa01115, CHEM\xa01125, CHEM\xa01110, CHEM\xa01130, CHEM\xa01120, CHEM\xa01140'
#  'BIOL\xa03040, BIOL\xa01240, BIOL\xa01245, BIOL\xa01260, BIOL\xa01265, CHEM\xa01120'
#  'BIOL\xa03030' 'BIOL\xa01240, BIOL\xa01260, BIOL\xa01265, BIOL\xa01245'
#  'BIOL\xa01240, BIOL\xa01260, BIOL\xa01265, CHEM\xa01120, BIOL\xa01245'
#  'BIOL\xa01260, BIOL\xa01265, BIOL\xa01240, BIOL\xa01245' 'BIOL\xa04540'
#  'BIOL\xa03010' 'BIOL\xa03020, BIOL\xa03030' 'BIOL\xa03020'
#  'BIOL\xa03020, BIOL\xa03040' 'BIOL\xa03040, BIOL\xa03020'
#  'BIOL\xa01240, BIOL\xa01260, BIOL\xa01265, BIOL\xa04360, BIOL\xa03020, BIOL\xa03040, BIOL\xa01245'
#  'BIOL\xa03040' 'BIOL\xa03010, BIOL\xa03030'
#  'BIOL\xa03020, BIOL\xa03040, BIOL\xa04630'
#  'BIOL\xa03020, BIOL\xa03040, BIOL\xa04640' 'BIOL\xa04480'
#  'BIOL\xa03020, BIOL\xa03030, BIOL\xa03040' 'MATH\xa01520'
#  'BIOL\xa01240, PHYS\xa01610' 'BME\xa03200, ECE\xa02001, ECE\xa02002'
#  'BME\xa02000, ECE\xa02001, ECE\xa02002, MATH\xa03550'
#  'BME\xa03100, ECE\xa03150, BME\xa02200, BIOL\xa02600, BME\xa04930'
#  'PHYS\xa01610'
#  'BME\xa02000, CSCI\xa01060, BME\xa03200, MATH\xa03550, PHYS\xa03410'
#  'BME\xa03200, CHEM\xa01120' 'BME\xa03400, BME\xa03100, BME\xa03300'
#  'BME\xa03100, ECE\xa03150, BME\xa02000, BME\xa02200, BIOL\xa02600'
#  'BME\xa03100' 'BME\xa02000, BME\xa03100'
#  'BME\xa02200, BIOL\xa02600, BME\xa04930, BME\xa03200, BME\xa03400'
#  'BME\xa03200' 'BIOL\xa02600, BME\xa02200, BME\xa03300'
#  'BME\xa03300, BME\xa04400'
#  'BME\xa03400, BIOL\xa02600, BME\xa02200, PHYS\xa03410, STAT\xa03850, MATH\xa03850'
#  'BME\xa03300, BME\xa04400, STAT\xa03850, MATH\xa03850' 'BME\xa04400'
#  'BME\xa02000, BME\xa03100, BME\xa03300' 'BME\xa04600' 'BIOL\xa01240'
#  'BME\xa03150, BME\xa03840' 'BME\xa04950' 'BLS\xa01850'
#  'BIOL\xa03020, PPY\xa02540, HSCI\xa03300, HSCI\xa03310, HSCI\xa03400, HSCI\xa03410, HSCI\xa03510'
#  'BLS\xa02850' 'BIOL\xa03020, CHEM\xa02410' 'BLS\xa04110' 'BLS\xa04411'
#  'BIOL\xa01100, BIOL\xa01240, CHEM\xa01120' 'MATH\xa01300, STAT\xa01300'
#  'BLS\xa03850' 'MATH\xa01320, MATH\xa01400' 'BST\xa03000, BST\xa03100'
#  'MATH\xa02530' 'BST\xa04100' 'BREW\xa01000'
#  'BIZ\xa01000, BIZ\xa01001, BIZ\xa01100'
#  'BIZ\xa01000, BIZ\xa01001, BIZ\xa01002'
#  'ACCT\xa02200, ACCT\xa02220, ECON\xa01900, ECON\xa03120, ECON\xa03140, FIN\xa03010, IB\xa02000, MGT\xa02000, MGT\xa03000, MKT\xa03000, BIZ\xa03000, BTM\xa02000, OPM\xa02070, OPM\xa03050, MGT\xa04000'
#  'BIZ\xa02300' 'BTM\xa02000' 'BTM\xa02500'
#  'BTM\xa02000, ACCT\xa02200, OPM\xa03050' 'BTM\xa03810' 'BTM\xa03700'
#  'BTM\xa03100' 'BTM\xa03100, BIZ\xa03000' 'CSO\xa01000' 'CSO\xa02000'
#  'CHEM\xa01080'
#  'CHEM\xa01050, CHEM\xa01030, MATH\xa01200, MATH\xa01320, MATH\xa01400, MATH\xa01510, MATH\xa01520'
#  'CHEM\xa01110, CHEM\xa01130' 'CHEM\xa01115, CHEM\xa01140, CHEM\xa01120'
#  'CHEM\xa01050, CHEM\xa01030, MATH\xa01400'
#  'CHEM\xa01080, CHEM\xa01085, CHEM\xa01480' 'CHEM\xa01120, CHEM\xa01140'
#  'CHEM\xa01120, CHEM\xa01140, CHEM\xa01125'
#  'CHEM\xa01120, CHEM\xa01140, CHEM\xa01125, CHEM\xa02410, CHEM\xa02430'
#  'CHEM\xa02410' 'CHEM\xa02415, CHEM\xa02435, CHEM\xa02420, CHEM\xa02440'
#  'CHEM\xa02430' 'CHEM\xa02435, CHEM\xa02440, CHEM\xa02430'
#  'CHEM\xa02440, CHEM\xa02420, CHEM\xa02200' 'CHEM\xa02200, MATH\xa01520'
#  'CHEM\xa03330' 'CHEM\xa02410, CHEM\xa02430'
#  'CHEM\xa02200, CHEM\xa02205, CHEM\xa02420, CHEM\xa02440, PHYS\xa01330, PHYS\xa01630'
#  'CHEM\xa02200, CHEM\xa02205, CHEM\xa02440, CHEM\xa02420, CHEM\xa02445'
#  'CHEM\xa02440, CHEM\xa02420, CHEM\xa02445, CHEM\xa02425'
#  'CHEM\xa02410, CHEM\xa02420, CHEM\xa02430, CHEM\xa02440'
#  'CHEM\xa02420, CHEM\xa02440' 'CHEM\xa04500'
#  'CHEM\xa02420, CHEM\xa02440, CHEM\xa02200'
#  'CHEM\xa02205, CHEM\xa02425, CHEM\xa02445, CHEM\xa04610' 'CHEM\xa04610'
#  'CHEM\xa04615' 'CHEM\xa02420, CHEM\xa02200, CHEM\xa03330' 'CHIN\xa01010'
#  'CHIN\xa01020' 'CHIN\xa02010' 'CHIN\xa02020' 'CHIN\xa03010'
#  'CVNG\xa01010' 'CVNG\xa01020, MATH\xa01510' 'CVNG\xa02010, GIS\xa04010'
#  'CVNG\xa01001' 'CVNG\xa01000, MATH\xa01510' 'CHEM\xa01110' 'CHEM\xa01115'
#  'CVNG\xa03030' 'MATH\xa03850' 'CVNG\xa03010, CVNG\xa03030' 'CVNG\xa03090'
#  'CVNG\xa03010' 'CVNG\xa03150' 'CVNG\xa03130' 'CVNG\xa03110'
#  'CVNG\xa03040, CVNG\xa03090, CVNG\xa03110, CVNG\xa03130, CVNG\xa03150'
#  'ENGL\xa01900' 'CMM\xa01000' 'ENGL\xa01900, EAP\xa01900' 'CMM\xa02100'
#  'CMM\xa02100, CMM\xa02120' 'CMM\xa02800'
#  'CMM\xa02100, CMM\xa03600, CMM\xa03700, CMM\xa03500'
#  'CMM\xa02100, CMM\xa03700, CMM\xa03600, CMM\xa03500'
#  'CMM\xa02000, CMM\xa02800'
#  'CMM\xa02800, CMM\xa03600, CMM\xa03700, MKT\xa03000, CMM\xa03500, CMM\xa04700'
#  'CMM\xa03500'
#  'CMM\xa02800, CMM\xa03600, CMM\xa03700, MKT\xa03400, CMM\xa03500'
#  'CMM\xa04700' 'CMM\xa02100, CMM\xa02120, CMM\xa01000, CMM\xa01200'
#  'ENGL\xa04005' 'CIS\xa01375' 'CIS\xa01600, CIS\xa02750'
#  'CIS\xa01600, MATH\xa01200' 'CIS\xa01375, CIS\xa01600'
#  'CIS\xa01600, CIS\xa02875' 'CIS\xa03300' 'CIS\xa03000'
#  'CIS\xa03300, CIS\xa03600' 'CIS\xa03150, CIS\xa03300' 'CIS\xa03700'
#  'CIS\xa03250' 'CIS\xa03100'
#  'MATH\xa01510, MATH\xa01320, MATH\xa01520, MATH\xa02530'
#  'CSCI\xa01010, BME\xa02000, CVNG\xa01500, MATH\xa03850, STAT\xa03850, ECE\xa01001, GIS\xa04090, MATH\xa01200, MATH\xa01320'
#  'PHIL\xa02050' 'CSCI\xa01300, MATH\xa01660' 'CSCI\xa02100'
#  'CSCI\xa02500, ECE\xa02205, ECE\xa03217, ECE\xa03225'
#  'CSCI\xa02100, MATH\xa01660, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'CSCI\xa02300' 'ECE\xa03217, CSCI\xa02100' 'CSCI\xa02100, ECE\xa03217'
#  'CSCI\xa03100' 'CSCI\xa03300' 'CSCI\xa02510' 'CSCI\xa02510, CSCI\xa03500'
#  'STAT\xa03850, CSCI\xa02100, MATH\xa02530' 'CSCI\xa04750'
#  'CSCI\xa02100, MATH\xa02530, MATH\xa03110, MATH\xa03120' 'CSCI\xa04961'
#  'ENGL\xa01500, EAP\xa01500' 'CORE\xa01500, CORE\xa01000' 'EDI\xa02000'
#  'EDI\xa04100' 'EDI\xa03305' 'EDI\xa03300' 'EDI\xa03310' 'EDI\xa03325'
#  'EDI\xa03320' 'EDI\xa03345' 'EDI\xa03340' 'EDI\xa03355' 'EDI\xa03350'
#  'EDI\xa03505' 'EDI\xa03500' 'EDI\xa03525' 'EDI\xa03545' 'EDI\xa03540'
#  'EDI\xa02940' 'EDI\xa02000, EDI\xa04100, EDI\xa03000'
#  'EDI\xa03000, EDI\xa03070'
#  'EDI\xa03200, EDI\xa03300, EDI\xa03320, EDI\xa03310, EDI\xa03340, EDF\xa02240, EDSP\xa04480'
#  'EDI\xa03550' 'DANC\xa02100' 'DANC\xa02200' 'DANC\xa02300' 'DATA\xa01800'
#  'DATA\xa01800, STAT\xa03850, CSCI\xa02100' 'DATA\xa04961'
#  'EAS\xa01430, CHEM\xa01110' 'EAS\xa01430, EAS\xa01435'
#  'EAS\xa01420, PHYS\xa01610' 'EAS\xa01420, EAS\xa01430, EAS\xa01450'
#  'BIOL\xa01240, BIOL\xa01245, CHEM\xa01110, CHEM\xa01115, EAS\xa01420, EAS\xa01430, EAS\xa01450'
#  'EAS\xa01420, MATH\xa01510, PHYS\xa01310, PHYS\xa01610' 'EAS\xa01420'
#  'EAS\xa02485, EAS\xa02480' 'EAS\xa02440'
#  'EAS\xa02440, PHYS\xa01610, MATH\xa01520'
#  'EAS\xa03330, PHYS\xa01630, MATH\xa02530' 'EAS\xa03330' 'EAS\xa02530'
#  'EAS\xa01430' 'EAS\xa02400' 'CHEM\xa01110, EAS\xa01430' 'EAS\xa04200'
#  'EAS\xa01430, EAS\xa01450, CHEM\xa01110, CHEM\xa01120'
#  'EAS\xa02200, EAS\xa02400, PHYS\xa01310, PHYS\xa01610' 'EAS\xa04300'
#  'EAS\xa01430, EAS\xa04300, PHYS\xa01310, PHYS\xa01610, MATH\xa01510'
#  'EAS\xa01420, EAS\xa01430, EAS\xa01450, MATH\xa01510'
#  'EAS\xa04440, MATH\xa03550' 'EAS\xa03330, EAS\xa04440'
#  'EAS\xa04410, EAS\xa04415' 'MATH\xa03550, PHYS\xa01610'
#  'EAS\xa04220, EAS\xa04440'
#  'MATH\xa01200, MATH\xa01320, MATH\xa01400, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa01900, OPM\xa02070'
#  'ECON\xa01900, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa03140, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa03120, ECON\xa03140, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa03120, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa03140, OPM\xa02070, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa03010, ECON\xa03120, ECON\xa03140, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'ECON\xa01900, ECON\xa03120, ECON\xa03140' 'ECON\xa03120, ECON\xa03140'
#  'EDUC\xa01015, EDUC\xa01025'
#  'EDUC\xa01010, EDUC\xa01020, EDUC\xa01030, EDUC\xa01040, EDUC\xa01050, EDUC\xa01100'
#  'EDUC\xa01025, EDUC\xa02100, EDUC\xa02150, EDUC\xa02200, EDUC\xa02310, EDUC\xa02320, EDUC\xa02330, EDUC\xa02400, EDUC\xa02410'
#  'EDUC\xa01030, EDUC\xa01040, EDUC\xa01050' 'EDUC\xa01010, EDUC\xa01020'
#  'EDUC\xa01050, EDUC\xa01200' 'EDUC\xa02310' 'EDUC\xa02310, EDUC\xa02200'
#  'EDUC\xa01300' 'EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa03000, EDUC\xa03150, EDUC\xa03310, EDUC\xa03320, EDUC\xa03330, EDUC\xa03335, EDUC\xa03340, EDUC\xa03350, EDUC\xa03440, EDUC\xa03470, EDUC\xa03480, EDUC\xa03490, EDUC\xa03500, EDUC\xa03550, EDUC\xa03600, EDUC\xa03700, EDUC\xa03800'
#  'EDUC\xa02150, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa02310, EDUC\xa02320, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa02100, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa02200, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa02310, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa01300, EDUC\xa03440, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa03330, EDUC\xa03500, EDUC\xa03015, EDUC\xa03025, EDUC\xa03440'
#  'EDUC\xa02100, EDUC\xa02200, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa02330, EDUC\xa03335, EDUC\xa03550, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa03330, EDUC\xa03500, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa03015, EDUC\xa03025, EDUC\xa04000, EDUC\xa04200, EDUC\xa04310, EDUC\xa04150, EDUC\xa04400'
#  'EDUC\xa03015, EDUC\xa03025, EDUC\xa03150'
#  'EDUC\xa03340, EDUC\xa03015, EDUC\xa03025'
#  'EDUC\xa03015, EDUC\xa03025, EDUC\xa03600' 'EDUC\xa04200'
#  'MATH\xa01520, PHYS\xa01630' 'ECE\xa02001' 'PHYS\xa01610, MATH\xa01520'
#  'ECE\xa02101' 'MATH\xa02530, BME\xa02000, CSCI\xa01060, CSCI\xa01300'
#  'ECE\xa03150' 'ECE\xa02102, MATH\xa03550' 'ECE\xa03130' 'ECE\xa03131'
#  'ECE\xa02001, ECE\xa02102, MATH\xa03550'
#  'CSCI\xa01060, CSCI\xa01300, BME\xa02000, ECE\xa03150' 'ECE\xa02205'
#  'ECE\xa03205, ECE\xa03225' 'CSCI\xa01060, BME\xa02000, CSCI\xa01300'
#  'ECE\xa03225' 'ECE\xa03140' 'ECE\xa04160' 'ECE\xa03131, MATH\xa03550'
#  'ECE\xa03150, MATH\xa03550' 'ECE\xa03150, ECE\xa03052' 'ECE\xa03110'
#  'ECE\xa03150, MATH\xa03850, ECE\xa03052, CSCI\xa01060, CSCI\xa01300, BME\xa02000'
#  'ECE\xa02205, ECE\xa03131' 'CSCI\xa03500' 'ECE\xa04800'
#  'EMGT\xa01500, EMGT\xa01600, EMGT\xa01710' 'EMGT\xa01500, EMGT\xa02900'
#  'EMGT\xa01500' 'EMGT\xa01500, EMGT\xa01600, EMGT\xa02900, EMGT\xa04760'
#  'ENGL\xa01500' 'ENGL\xa01900, PHIL\xa02050' 'ENGL\xa03850'
#  'EAP\xa01500, ENGL\xa01500' 'MATH\xa01400, MATH\xa01320'
#  'ANAT\xa01000, PPY\xa02540' 'PHYS\xa01220' 'DIET\xa02080, DPT\xa03230'
#  'ANAT\xa01000, PPY\xa02540, BIOL\xa04460, DIET\xa05690' 'STAT\xa01100'
#  'ACCT\xa02200, ACCT\xa02220, OPM\xa02070, ECON\xa01900'
#  'FIN\xa03330, FIN\xa03630' 'FIN\xa03010' 'FIN\xa04160'
#  'FIN\xa03010, FIN\xa03330, FIN\xa03630'
#  'FIN\xa03330, FIN\xa03630, BIZ\xa03000' 'FSCI\xa01150' 'FSCI\xa01550'
#  'FSCI\xa01250' 'FSCI\xa02150' 'FSCI\xa02550'
#  'FSCI\xa02250, MATH\xa01200, MATH\xa01400, MATH\xa01320, MATH\xa01510'
#  'FSCI\xa03550' 'FSCI\xa03700, FSCI\xa03750' 'FSCI\xa04100' 'FRSC\xa02600'
#  'FRSC\xa04610' 'FRSC\xa02600, FRSC\xa04550, FRSC\xa04551'
#  'FRSC\xa02600, FRSC\xa03630, FRSC\xa03620' 'FREN\xa01010' 'FREN\xa01020'
#  'FREN\xa02010' 'FREN\xa03030, FREN\xa03040' 'GIS\xa02010' 'GIS\xa04010'
#  'GIS\xa04040' 'MATH\xa01510, GIS\xa04040, GIS\xa04090'
#  'GIS\xa04010, GIS\xa04040' 'GIS\xa02010, GIS\xa02050' 'GR\xa01010'
#  'GR\xa01020' 'GR\xa02010' 'GR\xa03010, GR\xa03020, GR\xa03210'
#  'GK\xa01010' 'GK\xa01020' 'GK\xa02010' 'HCE\xa02010'
#  'HSCI\xa03300, HSCI\xa03400, ANAT\xa01000, PPY\xa02540, HIM\xa04750'
#  'HIM\xa03000' 'HIM\xa03200' 'HIM\xa03000, HIM\xa03600'
#  'ANAT\xa01000, PPY\xa02540, HSCI\xa03300, HSCI\xa03310, HSCI\xa03400, HSCI\xa03410, HSCI\xa02200'
#  'HMP\xa01300' 'ECON\xa01900, HMP\xa01300' 'ACCT\xa02200, HMP\xa03200'
#  'MATH\xa01300, OPM\xa02070, STAT\xa01300, PSY\xa02050, BST\xa03100, HMP\xa01300'
#  'ACCT\xa02200, HMP\xa02500, HMP\xa03200' 'HSCI\xa02000, IPE\xa02100'
#  'HSCI\xa02200, BIOL\xa01240, BIOL\xa01260, CHEM\xa01110, CHEM\xa01120, CHEM\xa01080'
#  'HSCI\xa02200, BIOL\xa01240, CHEM\xa01110, BIOL\xa01260, CHEM\xa01120, CHEM\xa01080'
#  'MATH\xa01300, STAT\xa01300, OPM\xa02070, ENGL\xa01900, CMM\xa01200'
#  'HSCI\xa03300, HSCI\xa03310, HSCI\xa03400, HSCI\xa03410, PPY\xa02540, ANAT\xa01000'
#  'HSCI\xa03200' 'HSCI\xa02100, HSCI\xa03700, ORES\xa02320'
#  'HIST\xa01110, HIST\xa01120'
#  'HMGT\xa03000, HMGT\xa03200, HMGT\xa03400, HMGT\xa03600, HMGT\xa04200'
#  'PST\xa01500' 'CORE\xa01905, HUM\xa02100' 'CORE\xa01605' 'SERV\xa01000'
#  'IB\xa02000' 'IPE\xa02100, IPE\xa01100, NURS\xa03100' 'IPE\xa04200'
#  'IPE\xa02100, IPE\xa04200' 'ITAL\xa01010' 'ITAL\xa01020, ITAL\xa01200'
#  'ITAL\xa02010' 'ITAL\xa03010' 'ITAL\xa03020' 'ITAL\xa03010, ITAL\xa03020'
#  'LATN\xa01010' 'LATN\xa01020' 'LATN\xa02010'
#  'MRI\xa04310, MRI\xa04320, MRI\xa04330, MRI\xa04340, MRI\xa04350'
#  'MGT\xa03000'
#  'MGT\xa03200, MGT\xa03201, MGT\xa03000, ACCT\xa02200, MGT\xa02000'
#  'ACCT\xa02200, ACCT\xa02220, ECON\xa01900, ECON\xa03120, ECON\xa03140, FIN\xa03010, IB\xa02000, MGT\xa02000, MGT\xa03000, MKT\xa03000, OPM\xa02070, OPM\xa03050, BIZ\xa03000, BTM\xa02000, BIZ\xa04000'
#  'MGT\xa03100' 'MGT\xa03200, MGT\xa03201, MGT\xa03210' 'MGT\xa03300'
#  'MGT\xa03400, MKT\xa03500, ECON\xa04500, MGT\xa03301, MGT\xa04401, MGT\xa04914, MGT\xa04403, MGT\xa03401, MGT\xa03800'
#  'MGT\xa02000' 'OPM\xa02070' 'MGT\xa03000, MGT\xa03200, MGT\xa03201'
#  'MGT\xa03000, MGT\xa03100, MGT\xa03300' 'MGT\xa03000, MGT\xa03400'
#  'MKT\xa03000' 'MKT\xa03000, MGT\xa03400' 'MATH\xa00240'
#  'MATH\xa00250, MATH\xa00260' 'MATH\xa01400' 'MATH\xa01510'
#  'MATH\xa02530, MATH\xa02660' 'MATH\xa03550' 'MATH\xa03120' 'MATH\xa04110'
#  'MATH\xa02530, MATH\xa03120' 'MATH\xa04210' 'MATH\xa04310'
#  'MATH\xa03850, STAT\xa03850, MATH\xa02530, MATH\xa01660, MATH\xa02660'
#  'MATH\xa03850, STAT\xa03850' 'MATH\xa04800, STAT\xa04800'
#  'MATH\xa03850, STAT\xa03850, MATH\xa03110, MATH\xa03120' 'SE\xa01700'
#  'PHYS\xa01610, MENG\xa01000' 'CVNG\xa02100, MENG\xa02100X, MATH\xa01520'
#  'ECE\xa01100, ECE\xa01200' 'MENG\xa03110, CVNG\xa04070, MENG\xa03510'
#  'MENG\xa03105, CVNG\xa03105X' 'MENG\xa02100X, CVNG\xa02100, MATH\xa02530'
#  'MENG\xa02150, MATH\xa03550' 'MENG\xa03105, CVNG\xa03105X, MENG\xa03200'
#  'ECE\xa02001, ECE\xa02002' 'CHEM\xa01110, MENG\xa03105, CVNG\xa03105X'
#  'MENG\xa01011, MENG\xa03510' 'MENG\xa03010' 'MENG\xa04004'
#  'MENG\xa03010, MENG\xa04450'
#  'CSCI\xa01060, CSCI\xa01300, MENG\xa02310, MENG\xa03200' 'MENG\xa04300'
#  'ECE\xa02001, MENG\xa02450, MENG\xa02400' 'MENG\xa03910' 'MENG\xa03915'
#  'BLS\xa04510'
#  'MLS\xa04701, MLS\xa04710, MLS\xa04740, MLS\xa04750, MLS\xa04760, MLS\xa04780, MLS\xa04790, MLS\xa04800, MLS\xa04811, MLS\xa04821'
#  'MLS\xa04701, MLS\xa04710, MLS\xa04821'
#  'MLS\xa04740, MLS\xa04750, MLS\xa04821' 'MLS\xa04800, MLS\xa04811'
#  'BLS\xa04110, BLS\xa04120, MLS\xa04150' 'BLS\xa04210, MLS\xa04250'
#  'BLS\xa04220' 'BLS\xa04310, MLS\xa04350'
#  'BLS\xa04510, MLS\xa04520, MLS\xa04550' 'BLS\xa03110, MLS\xa03150'
#  'MUSC\xa01260' 'MUSC\xa02270' 'MUSC\xa01270' 'MUSC\xa02500'
#  'MUSC\xa02280' 'PSY\xa01010, NEUR\xa03400' 'NEUR\xa03400, BIOL\xa03400X'
#  'NEUR\xa03400, NEUR\xa03500, NEUR\xa03550' 'NEUR\xa03500'
#  'PPY\xa02540, ANAT\xa01000' 'ANAT\xa01000, NURS\xa01430, PPY\xa02540'
#  'ANAT\xa01000, NURS\xa01430, NURS\xa02500, NURS\xa03200, PPY\xa02540, NURS\xa01500, BIOL\xa01600, BIOL\xa01930'
#  'STAT\xa01100, MATH\xa01300, STAT\xa01300, PSY\xa02050'
#  'NURS\xa02500, NURS\xa02520'
#  'NURS\xa02500, NURS\xa02510, NURS\xa02520, NURS\xa03330, NURS\xa03360, NURS\xa03200'
#  'NURS\xa01430, NURS\xa02500, ANAT\xa01000, PPY\xa02540'
#  'NURS\xa02500, NURS\xa02520, ANAT\xa01000, PPY\xa02540'
#  'ANAT\xa01000, NURS\xa01500, BIOL\xa01600, BIOL\xa01930, PPY\xa02540'
#  'NURS\xa02500, NURS\xa02510, NURS\xa03360'
#  'NURS\xa02500, NURS\xa02515, NURS\xa02520, NURS\xa03360'
#  'NURS\xa02500, NURS\xa03200, NURS\xa03330, NURS\xa03360, NURS\xa02510, NURS\xa02520'
#  'NURS\xa02500, NURS\xa02515, NURS\xa02520, NURS\xa03200, NURS\xa03330, NURS\xa03360'
#  'NURS\xa02510, NURS\xa03200, NURS\xa03330, NURS\xa03360'
#  'NURS\xa02500, NURS\xa02515, NURS\xa02520, NURS\xa03200, NURS\xa03330, NURS\xa03360, NURS\xa03565'
#  'NURS\xa03447'
#  'NURS\xa03360, NURS\xa03330, NURS\xa03200, NURS\xa02500, NURS\xa02510, NURS\xa02520'
#  'NURS\xa03575' 'NURS\xa03565' 'NURS\xa03100' 'NURS\xa04100'
#  'NURS\xa03430, NURS\xa03440, NURS\xa03460, NURS\xa03470, NURS\xa03480, NURS\xa03490'
#  'NURS\xa03435, NURS\xa03445' 'NURS\xa04300' 'NURS\xa04150'
#  'NURS\xa04305, NURS\xa04355' 'NURS\xa03360, NURS\xa05170' 'NURS\xa03360'
#  'NURS\xa03460' 'NURS\xa04507' 'DIET\xa02080' 'DIET\xa02510'
#  'DIET\xa02510, DIET\xa02750' 'CHEM\xa01120, DIET\xa02510, DIET\xa02080'
#  'DIET\xa03190'
#  'DIET\xa02080, BIOL\xa01240, BIOL\xa01245, CHEM\xa01120, CHEM\xa01125, CHEM\xa02410, CHEM\xa03600, PPY\xa02540'
#  'DIET\xa03850' 'DIET\xa04100' 'DIET\xa04110'
#  'DIET\xa03700, MGT\xa03000, BLS\xa04510, ECON\xa01900, ACCT\xa02200'
#  'DIET\xa04350' 'DIET\xa02510, DIET\xa04100' 'DIET\xa02100' 'DIET\xa04870'
#  'DIET\xa03750'
#  'OPM\xa02070, MATH\xa01320, MATH\xa01510, MATH\xa01520, MATH\xa02530'
#  'OPM\xa03050' 'CIS\xa02300' 'ORLD\xa02000' 'ORLD\xa01800' 'ORLD\xa01000'
#  'ORLD\xa03800' 'OSTD\xa03005' 'OSTD\xa03205, OSTD\xa03305, OSTD\xa04105'
#  'CHEM\xa03600, CHEM\xa04610, BIOL\xa03020' 'CORE\xa01005' 'CORE\xa01700'
#  'ENGL\xa01900, ENGL\xa01920, PHIL\xa02050' 'PHIL\xa02050, MATH\xa01200'
#  'PHIL\xa04040' 'PHIL\xa02050, PHIL\xa01700, PHIL\xa01707'
#  'PHIL\xa01700, PHIL\xa01707' 'PHIL\xa01700, PHIL\xa02050' 'PLJ\xa01010'
#  'PLJ\xa01010, PLJ\xa01020' 'PLJ\xa01050' 'PLJ\xa01050, PLJ\xa03050'
#  'PLJ\xa03000, PHIL\xa02050'
#  'PHIL\xa01700, PHIL\xa02050, PHIL\xa03250, PHIL\xa03300, PHIL\xa04500, PHIL\xa04600'
#  'MATH\xa01200, MATH\xa01400' 'PHYS\xa01310' 'MATH\xa01510, MATH\xa01400'
#  'PHYS\xa01610, PHYS\xa01620, PHYS\xa01640' 'PHYS\xa01610, PHYS\xa01620'
#  'PHYS\xa01630' 'PHYS\xa02610, MATH\xa01520' 'MATH\xa03550, PHYS\xa01630'
#  'PHYS\xa03511' 'PHYS\xa03510' 'PHYS\xa02910'
#  'CHEM\xa01110, MATH\xa02530, PHYS\xa01630' 'PHYS\xa03410'
#  'PHYS\xa02610, PHYS\xa03110' 'PHYS\xa03910' 'PHYS\xa03915' 'POLS\xa01000'
#  'POLS\xa01000, POLS\xa01600' 'POLS\xa01100, POLS\xa01150'
#  'POLS\xa02000, POLS\xa01100, POLS\xa01150' 'POLS\xa02000, POLS\xa01150'
#  'POLS\xa01100, POLS\xa01150, POLS\xa02100, POLS\xa03100'
#  'POLS\xa02000, POLS\xa01150, POLS\xa01100'
#  'POLS\xa02000, POLS\xa01500, POLS\xa03500, POLS\xa02820, POLS\xa03810'
#  'POLS\xa02000, POLS\xa01600, POLS\xa02600, POLS\xa03600, POLS\xa02820, POLS\xa03810'
#  'POLS\xa01600, POLS\xa02600, POLS\xa02000'
#  'POLS\xa02000, POLS\xa01700, POLS\xa02700, POLS\xa03710, POLS\xa03720, POLS\xa03770'
#  'POLS\xa02000' 'PG\xa01010' 'PG\xa01020' 'PG\xa02010'
#  'PLS\xa01000, PLS\xa04965, PLS\xa02000'
#  'BIOL\xa01240, BIOL\xa01245, BIOL\xa01260, BIOL\xa01265, CHEM\xa01120, CHEM\xa01125'
#  'CIS\xa02875' 'PMGT\xa01010' 'ENGL\xa01900, PMGT\xa01010'
#  'CIS\xa02875, ENGL\xa01900, PMGT\xa01010' 'PMGT\xa02020'
#  'PMGT\xa01020, PMGT\xa02020' 'PMGT\xa01030' 'PMGT\xa01030, PMGT\xa02010'
#  'PMGT\xa03020' 'PMGT\xa02010, PMGT\xa03020' 'PMGT\xa04010, PMGT\xa04030'
#  'PSY\xa02050' 'PSY\xa03210, PSY\xa03230' 'PSY\xa01010, PSY\xa03300'
#  'PSY\xa03300' 'PSY\xa01010, PSY\xa02050'
#  'PSY\xa03460, PSY\xa01010, PSY\xa02050'
#  'PSY\xa01010, PSY\xa02050, PSY\xa04060' 'PUBH\xa02100'
#  'HMP\xa01300, PUBH\xa02300, PUBH\xa03200, PUBH\xa04000, PUBH\xa04100, BST\xa03100, EPI\xa04000, HCE\xa03100'
#  'RUSS\xa01010' 'RUSS\xa01020' 'RUSS\xa02010' 'RUSS\xa02020'
#  'RUSS\xa03010' 'RUSS\xa03250' 'CIS\xa01150' 'CIS\xa02875, SSI\xa01500'
#  'SSI\xa03000' 'CORE\xa01205, CIS\xa02875, SSI\xa01500'
#  'CIS\xa03300, SSI\xa01500' 'SSI\xa03020' 'SSI\xa03010' 'SSI\xa03030'
#  'SSI\xa02000' 'SSI\xa03040' 'SSI\xa04200' 'SSI\xa04500' 'SWRK\xa03300'
#  'SWRK\xa03300, SWRK\xa03400, SWRK\xa03500, SWRK\xa01000'
#  'SWRK\xa04100, SWRK\xa04150' 'SOC\xa02000'
#  'PSY\xa01010, SOC\xa01100, SOC\xa01110, SOC\xa01120' 'SOC\xa04650'
#  'SOC\xa04640, SOC\xa04650, SOC\xa04660' 'SPAN\xa01010'
#  'SPAN\xa01020, SPAN\xa01200' 'SPAN\xa02010' 'SPAN\xa03010'
#  'SPAN\xa03010, SPAN\xa03020' 'SPAN\xa04000' 'SPAN\xa04200' 'EDSP\xa04530'
#  'EDSP\xa04310' 'EDSP\xa03700, EDSP\xa04310' 'EDSP\xa03700'
#  'SLHS\xa02000, SLHS\xa02400' 'SLHS\xa03700' 'SLHS\xa04300'
#  'SLHS\xa02000, SLHS\xa04300'
#  'MATH\xa00260, MATH\xa01200, MATH\xa01400, MATH\xa01320, MATH\xa01510, MATH\xa00265'
#  'STAT\xa01300' 'STAT\xa03850, MATH\xa03850' 'THR\xa01500'
#  'THR\xa02510, THR\xa02530, THR\xa02540' 'THR\xa03500'
#  'THR\xa02510, THR\xa02530' 'THR\xa02510' 'THR\xa03700' 'THEO\xa01600'
#  'THEO\xa03430, THEO\xa03435' 'WGST\xa02100']
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Prerequisites, dtype: object

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv(r'C:\Users\guffe\Desktop\Computer_Science\Projects\Optimal-Flowsheets\Projects\CSV_iterations\cleaned_slu_courses2.csv')

# Function to clean up and format prerequisites into a PostgreSQL-friendly array format
def format(prereqs):
    if pd.isna(prereqs) or prereqs.strip() == 'False':
        return '{}'  # Use empty array if prerequisites are NaN or False
    # Remove any surrounding quotes and ensure it is enclosed in curly braces
    prereqs = prereqs.replace('"', '').strip()
    if not prereqs.startswith('{'):
        prereqs = '{' + prereqs + '}'
    return prereqs


# Apply the transformations
df['Prerequisites'] = df['Prerequisites'].apply(format)
df['Course Details'] = df['Course Details'].apply(format)

# Save the modified dataframe to a new CSV file
df.to_csv('cleaned_courses3.csv', index=False, quotechar="'")

# %%
df.head(25)
# Out:
#            Prerequisites  Concurrent Enrollment  \
# 0                     {}                  False
# 1                     {}                  False
# 2                     {}                  False
# 3                     {}                  False
# 4                     {}                  False
# 5                     {}                  False
# 6                     {}                  False
# 7                     {}                  False
# 8                     {}                  False
# 9                     {}                  False
# 10                    {}                  False
# 11                    {}                  False
# 12                    {}                  False
# 13                    {}                  False
# 14                    {}                  False
# 15                    {}                  False
# 16                    {}                  False
# 17                    {}                  False
# 18                    {}                  False
# 19                    {}                  False
# 20                    {}                  False
# 21                    {}                  False
# 22                    {}                  False
# 23                    {}                  False
# 24  {BIZ 1000, BIZ 1001}                  False
#
#                              Major Course Name  \
# 0   Academic English Program (AEP)    AEP 0100
# 1   Academic English Program (AEP)    AEP 0120
# 2   Academic English Program (AEP)    AEP 0130
# 3   Academic English Program (AEP)    AEP 0200
# 4   Academic English Program (AEP)    AEP 0220
# 5   Academic English Program (AEP)    AEP 0230
# 6   Academic English Program (AEP)    AEP 0250
# 7   Academic English Program (AEP)    AEP 0300
# 8   Academic English Program (AEP)    AEP 0310
# 9   Academic English Program (AEP)    AEP 0320
# 10  Academic English Program (AEP)    AEP 0330
# 11  Academic English Program (AEP)    AEP 0350
# 12  Academic English Program (AEP)    AEP 0400
# 13  Academic English Program (AEP)    AEP 0410
# 14  Academic English Program (AEP)    AEP 0411
# 15  Academic English Program (AEP)    AEP 0420
# 16  Academic English Program (AEP)    AEP 0430
# 17  Academic English Program (AEP)    AEP 0450
# 18  Academic English Program (AEP)    AEP 0500
# 19  Academic English Program (AEP)    AEP 0510
# 20  Academic English Program (AEP)    AEP 0520
# 21  Academic English Program (AEP)    AEP 0530
# 22  Academic English Program (AEP)    AEP 0930
# 23  Academic English Program (AEP)    AEP 1410
# 24               Accounting (ACCT)   ACCT 2200
#
#                                        Course Details  Credits  Repeatable
# 0               Writing and Grammar Level 1: Beginner        4       False
# 1            Reading and Vocabulary Level 1: Beginner        4       False
# 2            Listening and Speaking Level 1: Beginner        4       False
# 3          Writing and Grammar Level 2: High Beginner        4       False
# 4       Reading and Vocabulary Level 2: High Beginner        4       False
# 5       Listening and Speaking Level 2: High Beginner        4       False
# 6      English through Service Level 2: High Beginner        1       False
# 7           Writing and Grammar Level 3: Intermediate        4       False
# 8            Exploring Cultures Level 3: Intermediate        3       False
# 9        Reading and Vocabulary Level 3: Intermediate        3       False
# 10       Listening and Speaking Level 3: Intermediate        4       False
# 11      English through Service Level 3: Intermediate        1       False
# 12     Writing and Grammar Level 4: High Intermediate        4       False
# 13     Contemporary Issues Level 4: High Intermediate        3       False
# 14  People, Places, Connections: An Introduction t...        3       False
# 15  Reading and Vocabulary Level 4: High Intermediate        3       False
# 16    Listening & Speaking Level 4: High Intermediate        4       False
# 17  English through Service Level 4: High Intermed...        1       False
# 18          Writing and Grammar Level 5: Low Advanced        4       False
# 19  Intercultural Communication Level 5: Low Advanced        3       False
# 20       Reading and Vocabulary Level 5: Low Advanced        3       False
# 21       Listening and Speaking Level 5: Low Advanced        4       False
# 22                                     Special Topics        4       False
# 23  People, Places, Connections: An Introduction t...        3       False
# 24                               Financial Accounting        3       False

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv(r'C:\Users\guffe\Desktop\Computer_Science\Projects\Optimal-Flowsheets\Projects\CSV_iterations\cleaned_slu_courses2.csv', encoding='utf-8')


# Make sure to use the exact column name, adjust 'Course Name' if needed
filtered_df = df[df['Course Name'].str.strip() == 'ACCT 2200']  # str.strip() helps remove any leading/trailing spaces

# Check if the filtered dataframe is empty
if filtered_df.empty:
    print("No data found for ACCT 2200.")
else:
    # Print the prerequisites for the course
    for index, row in filtered_df.iterrows():
        print(f"Course Name: {row['Course Name']}, Prerequisites: {row['Prerequisites']}")
# Out:
# No data found for ACCT 2200.

# %%
import pandas as pd

# Load the CSV file
file_path = 'path_to_your_csv_file.csv'
courses_df = pd.read_csv(file_path)

# Convert the 'prerequisites' column into a single string for each row
courses_df['prerequisites'] = courses_df['prerequisites'].apply(lambda x: ';'.join(x) if isinstance(x, list) else x)

# Save the modified DataFrame back to a CSV file
modified_file_path = 'modified_slu_courses.csv'
courses_df.to_csv(modified_file_path, index=False)

print(f"Modified CSV saved to {modified_file_path}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 # Load the CSV file
#       4 file_path = 'path_to_your_csv_file.csv'
#
# ModuleNotFoundError: No module named 'pandas'
